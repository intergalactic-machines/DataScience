# %%
import pandas as pd
from os import walk
import re
from os import listdir
from os.path import join
import matplotlib.pyplot as plt
import datetime
import numpy as np

# %%
path_nab = 'C:\\Users\\RJO7ABT\\Documents\\Bosch-MT\\Daten\\NAB\\artificialWithAnomaly\\'
files = [f for f in listdir(path_nab) if f.endswith('.csv')]

file_path = 'C:\\Users\\RJO7ABT\\Documents\\Bosch-MT\\Daten\\NAB\\artificialWithAnomaly\\art_daily_flatmiddle.csv'
#print(file_path)
df = pd.read_csv(file_path)
df.plot()
plt.show()

# %%
file_path = path_nab + str(file)
for file in files:
    file_path = path_nab + file
    print(file_path)
    df = pd.read_csv(file_path)
    #print(df.info(verbose=True), df.head(5))
    df.plot
    _, ax = plt.subplots(figsize=(20,10))
    ax.scatter(df['timestamp'].tolist(), df['value'], c='blue', s=100, marker='.')
    #clb = fig.colorbar(scatter)
    #clb.ax.set_title('Temperatur')
    # Label axes
    ax.set_ylabel("value")
    ax.set_xlabel("date")
    ax.set_title("title")
'''

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-b866a9a7b88f> in <module>()
#       1 _, ax = plt.subplots(figsize=(20,10))
# ----> 2 ax.scatter(datetime.datetime(df['timestamp']), df['value'], c='blue', s=100, marker='.')
#       3     #clb = fig.colorbar(scatter)
#       4     #clb.ax.set_title('Temperatur')
#       5     # Label axes
#
# C:\Users\RJO7ABT\.conda\envs\nupic2.7\lib\site-packages\pandas\core\series.pyc in wrapper(self)
#      95             return converter(self.iloc[0])
#      96         raise TypeError("cannot convert the series to "
# ---> 97                         "{0}".format(str(converter)))
#      98
#      99     return wrapper
#
# TypeError: cannot convert the series to <type 'int'>
